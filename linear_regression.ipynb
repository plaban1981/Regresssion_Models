# %% [markdown]
# <a href="https://colab.research.google.com/github/plaban1981/Regresssion_Models/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ROOT = "/content/drive/MyDrive/DAY 1"

# %%
import os
os.chdir(ROOT)

# %%
# !ls
# Out:
# linear_regression.ipynb

# %%
assert ROOT == os.getcwd()

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/DAY 1'

# %%
with open("test.txt", "w") as f:
  f.writelines("Hello everyone")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/DATA/Advertising.csv')
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df['total_spent'] = df['TV'] + df['radio'] + df["newspaper"]
df.head()
# Out:
#       TV  radio  newspaper  sales  total_spent
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
sns.scatterplot(data=df, x='total_spent', y='sales')

# %%
sns.regplot(data=df, x='total_spent', y='sales', color='red') #OLS

# %%
x = df['total_spent']
y = df['sales']

# %%
#help(sns.regplot)

# %%
#help(np.polyfit)

# %%
np.polyfit(x,y, deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
potential_spend = np.linspace(0,500,100) #x
potential_spend

# %%
help(np.linspace)

# %%
#y = m*x + b
predicted_sales = 0.04868788*potential_spend + 4.24302822
predicted_sales

# %%
sns.scatterplot(x='total_spent', y='sales', data=df) #scatter plot
plt.plot(potential_spend, predicted_sales, color='green') #line

# %%
spend = 200
predicted_sales = 0.04868788*spend + 4.24302822
predicted_sales
# Out:
# 13.98060422

# %%
#Y = B3x**3 + B2x**2 + B3x + B0
np.polyfit(x,y, deg=3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
pot_spend = np.linspace(0,500,100)

# %%
pred_sales = 3.07615033e-07*pot_spend**3 + -1.89392449e-04*pot_spend**2 + 8.20886302e-02*pot_spend + 2.70495053e+00
pred_sales

# %%
sns.scatterplot(x='total_spent', y='sales', data=df) #scatter plot
plt.plot(pot_spend, pred_sales, color='green') #line

# %%
fig,axes = plt.subplots(nrows=1, ncols=3, figsize=(16,6))

axes[0].plot(df['TV'], df['sales'], 'o')
axes[0].set_ylabel("sales")
axes[0].set_title("TV Spend")


axes[1].plot(df['radio'], df['sales'], 'o')
axes[1].set_ylabel("sales")
axes[1].set_title("Radio Spend")

axes[2].plot(df['newspaper'], df['sales'], 'o')
axes[2].set_ylabel("sales")
axes[2].set_title("Newspaper Spend")
# Out:
# Text(0.5, 1.0, 'Newspaper Spend')

# %%
sns.pairplot(df)
